# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %%
dados = pd.read_csv('todasRespostas.csv') #lendo o csv
dados
# Out:
#     Ate 18  Entre 18 e 30  Entre 30 e 60  Mais de 60  Solteiro  Casado  \
# 0    False           True          False       False      True   False
# 1    False           True          False       False      True   False
# 2    False           True          False       False      True   False
# 3    False           True          False       False      True   False
# 4    False          False           True       False     False    True
# 5    False           True          False       False      True   False
# 6    False           True          False       False      True   False
# 7    False           True          False       False     False    True
# 8    False           True          False       False     False    True
# 9    False           True          False       False      True   False
# 10   False           True          False       False      True   False
# 11   False          False           True       False     False    True
# ...

# %%
#calculando o suporte
suportes= apriori(dados, min_support=0.6, use_colnames=True)
suportes #imprime os suportes
# Out:
#       support                                           itemsets
# 0    0.837838                                    (Entre 18 e 30)
# 1    0.648649                                         (Solteiro)
# 2    0.918919                                     (Mora familia)
# 3    0.621622                         (Cartao de credito debito)
# 4    0.918919                                        (Qualidade)
# 5    0.864865                                    (Classificacao)
# 6    0.918919                                        (Confianca)
# 7    0.945946                                      (Facilidade )
# 8    0.945946             (Especificacoes do produto ou servico)
# 9    0.918919  (O nivel de confianca e popularidade da loja i...
# 10   0.864865                           (Prefere comprar online)
# 11   0.756757        (Utiliza aplicativos para realizar compras)
# 12   0.837838          (Leva em consideracao o prazo de entrega)
# ...

# %%
from mlxtend.frequent_patterns import association_rules
regras= association_rules(suportes, metric="confidence", min_threshold=0.88)
regras
# Out:
#                                             antecedents  \
# 0                                       (Entre 18 e 30)
# 1                                       (Entre 18 e 30)
# 2                                       (Entre 18 e 30)
# 3                                       (Entre 18 e 30)
# 4                                       (Entre 18 e 30)
# 5                                       (Entre 18 e 30)
# 6                                       (Entre 18 e 30)
# 7           (Utiliza aplicativos para realizar compras)
# 8                                 (Servico de delivery)
# 9                                            (Solteiro)
# 10                                           (Solteiro)
# 11                                           (Solteiro)
# 12                                          (Qualidade)
# 13                                       (Mora familia)
# 14                                       (Mora familia)
# 15                                      (Classificacao)
# ...
